# %%
# !pip install nltk scikit-learn numpy pandas -q

# %%
pip install --user wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\rishu\appdata\roaming\python\python312\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\rishu\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\rishu\anaconda3\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\rishu\anaconda3\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rishu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rishu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rishu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rishu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rishu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rishu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rishu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rishu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Importing the Dependencies**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from wordcloud import WordCloud
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# **Data Loading & Understanding**

# %%
# loading the dataset to a pandas dataframe
df = pd.read_csv("movies.csv")

# %%
df.shape
# Out:
# (4803, 24)

# %%
df.head(2)
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  ... runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...   162.0
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...   169.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
#
#                                                 cast  \
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...
#
#                                                 crew        director
# 0  [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...   James Cameron
# 1  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...  Gore Verbinski
#
# [2 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   object
#  3   homepage              1712 non-null   object
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   object
#  6   original_language     4803 non-null   object
#  7   original_title        4803 non-null   object
#  8   overview              4800 non-null   object
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   object
#  11  production_countries  4803 non-null   object
#  12  release_date          4802 non-null   object
#  13  revenue               4803 non-null   int64
#  14  runtime               4801 non-null   float64
#  15  spoken_languages      4803 non-null   object
#  16  status                4803 non-null   object
#  17  tagline               3959 non-null   object
#  18  title                 4803 non-null   object
#  19  vote_average          4803 non-null   float64
#  20  vote_count            4803 non-null   int64
#  21  cast                  4760 non-null   object
#  22  crew                  4803 non-null   object
#  23  director              4773 non-null   object
# dtypes: float64(3), int64(5), object(16)
# memory usage: 900.7+ KB

# %%
# filter the required columns for recommendation
required_columns = ["genres", "keywords", "overview", "title"]

df = df[required_columns]

# %%
df.shape
# Out:
# (4803, 4)

# %%
df.head()
# Out:
#                                      genres  \
# 0  Action Adventure Fantasy Science Fiction
# 1                  Adventure Fantasy Action
# 2                    Action Adventure Crime
# 3               Action Crime Drama Thriller
# 4          Action Adventure Science Fiction
#
#                                             keywords  \
# 0  culture clash future space war space colony so...
# 1  ocean drug abuse exotic island east india trad...
# 2         spy based on novel secret agent sequel mi6
# 3  dc comics crime fighter terrorist secret ident...
# 4  based on novel mars medallion space travel pri...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                       title
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter

# %%
# check for missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4775 non-null   object
#  1   keywords  4391 non-null   object
#  2   overview  4800 non-null   object
#  3   title     4803 non-null   object
# dtypes: object(4)
# memory usage: 150.2+ KB

# %%
df = df.dropna().reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4387 entries, 0 to 4386
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4387 non-null   object
#  1   keywords  4387 non-null   object
#  2   overview  4387 non-null   object
#  3   title     4387 non-null   object
# dtypes: object(4)
# memory usage: 137.2+ KB

# %%
df['combined'] = df['genres'] + ' ' + df['keywords'] + ' ' + df['overview']

# %%
df.head()
# Out:
#                                      genres  \
# 0  Action Adventure Fantasy Science Fiction
# 1                  Adventure Fantasy Action
# 2                    Action Adventure Crime
# 3               Action Crime Drama Thriller
# 4          Action Adventure Science Fiction
#
#                                             keywords  \
# 0  culture clash future space war space colony so...
# 1  ocean drug abuse exotic island east india trad...
# 2         spy based on novel secret agent sequel mi6
# 3  dc comics crime fighter terrorist secret ident...
# 4  based on novel mars medallion space travel pri...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             combined
# 0  Action Adventure Fantasy Science Fiction cultu...
# 1  Adventure Fantasy Action ocean drug abuse exot...
# 2  Action Adventure Crime spy based on novel secr...
# 3  Action Crime Drama Thriller dc comics crime fi...
# 4  Action Adventure Science Fiction based on nove...

# %%
df.tail()
# Out:
#                               genres  \
# 4382                           Drama
# 4383  Science Fiction Drama Thriller
# 4384           Action Crime Thriller
# 4385   Comedy Drama Romance TV Movie
# 4386                     Documentary
#
#                                                keywords  \
# 4382         gang audition police fake homeless actress
# 4383  distrust garage identity crisis time travel ti...
# 4384  united states\u2013mexico barrier legs arms pa...
# 4385  date love at first sight narration investigati...
# 4386               obsession camcorder crush dream girl
#
#                                                overview  \
# 4382  A young woman in L.A. is having a bad day: she...
# 4383  Friends/fledgling entrepreneurs invent a devic...
# 4384  El Mariachi just wants to play his guitar and ...
# 4385  "Signed, Sealed, Delivered" introduces a dedic...
# 4386  Ever since the second grade when he first saw ...
#
#                           title  \
# 4382                       Bang
# 4383                     Primer
# 4384                El Mariachi
# 4385  Signed, Sealed, Delivered
# 4386          My Date with Drew
#
#                                                combined
# 4382  Drama gang audition police fake homeless actre...
# 4383  Science Fiction Drama Thriller distrust garage...
# 4384  Action Crime Thriller united states\u2013mexic...
# 4385  Comedy Drama Romance TV Movie date love at fir...
# 4386  Documentary obsession camcorder crush dream gi...

# %%
data = df[['title', 'combined']]

# %%
data.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             combined
# 0  Action Adventure Fantasy Science Fiction cultu...
# 1  Adventure Fantasy Action ocean drug abuse exot...
# 2  Action Adventure Crime spy based on novel secr...
# 3  Action Crime Drama Thriller dc comics crime fi...
# 4  Action Adventure Science Fiction based on nove...

# %%
data.shape
# Out:
# (4387, 2)

# %%
# WordCloud for movie content
combined_text = " ".join(df['combined'])
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(combined_text)

# %%
# WordCloud to visualize the most common words in the movie content
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Most Common Words in Movie content")
plt.show()

# %%
# download nltk data
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
def preprocess_text(text):
    # Remove special characters and numbers
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    # Convert to lowercase
    text = text.lower()
    # Tokenize and remove stopwords
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    return " ".join(tokens)

# %%
# Apply preprocessing to the movie content
data['cleaned_text'] = df['combined'].apply(preprocess_text)
# Out:
# C:\Users\rishu\AppData\Local\Temp\ipykernel_18324\802455668.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cleaned_text'] = df['combined'].apply(preprocess_text)

# %%
data.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             combined  \
# 0  Action Adventure Fantasy Science Fiction cultu...
# 1  Adventure Fantasy Action ocean drug abuse exot...
# 2  Action Adventure Crime spy based on novel secr...
# 3  Action Crime Drama Thriller dc comics crime fi...
# 4  Action Adventure Science Fiction based on nove...
#
#                                         cleaned_text
# 0  action adventure fantasy science fiction cultu...
# 1  adventure fantasy action ocean drug abuse exot...
# 2  action adventure crime spy based novel secret ...
# 3  action crime drama thriller dc comics crime fi...
# 4  action adventure science fiction based novel m...

# %%
# Vectorization with TF-IDF
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
tfidf_matrix = tfidf_vectorizer.fit_transform(data['cleaned_text'])

# %%
# Compute Cosine Similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
print(cosine_sim[1])
# Out:
# [0.02901396 1.         0.03100093 ... 0.01749756 0.02801405 0.        ]

# %%
# Recommendation Function
def recommend_movies(movie_name, cosine_sim=cosine_sim, df=data, top_n=5):
    # Find the index of the movie
    idx = df[df['title'].str.lower() == movie_name.lower()].index
    if len(idx) == 0:
        return "Movie not found in the dataset!"
    idx = idx[0]

    # Get similarity scores
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1]

    # Get movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return top n similar movies
    return df[['title']].iloc[movie_indices]

# %%
data["title"]
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4382                                        Bang
# 4383                                      Primer
# 4384                                 El Mariachi
# 4385                   Signed, Sealed, Delivered
# 4386                           My Date with Drew
# Name: title, Length: 4387, dtype: object

# %%
# row_index = df[df['title'] == "Avengers: Age of Ultron"].index
row_index = df[df['title'] == "Batman v Superman: Dawn of Justice"].index
print(row_index)
# Out:
# Index([9], dtype='int64')

# %%
movie_name = data["title"][9]
print(movie_name)
# Out:
# Batman v Superman: Dawn of Justice

# %%
# Example Recommendation
print(f"Recommendations for the Movie {movie_name}")
recommendations = recommend_movies(movie_name)
print(recommendations)
# Out:
# Recommendations for the Movie Batman v Superman: Dawn of Justice
#                 title
# 14       Man of Steel
# 861       Superman II
# 424    Batman Returns
# 1401  Superhero Movie
# 3590         Defendor

# %%
pip install -r requirements.txt
# Out:
# Collecting streamlit==1.44.1 (from -r requirements.txt (line 1))
#   Downloading streamlit-1.44.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting numpy==2.2.4 (from -r requirements.txt (line 2))
#   Downloading numpy-2.2.4-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting pandas==2.2.3 (from -r requirements.txt (line 3))
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting scikit-learn==1.6.1 (from -r requirements.txt (line 4))
#   Downloading scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: nltk==3.9.1 in c:\users\rishu\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (3.9.1)
# Requirement already satisfied: joblib==1.4.2 in c:\users\rishu\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: requests==2.32.3 in c:\users\rishu\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (2.32.3)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: packaging<25,>=20 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (16.1.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (4.0.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\rishu\anaconda3\lib\site-packages (from streamlit==1.44.1->-r requirements.txt (line 1)) (6.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rishu\anaconda3\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rishu\anaconda3\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rishu\anaconda3\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\rishu\anaconda3\lib\site-packages (from scikit-learn==1.6.1->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rishu\anaconda3\lib\site-packages (from scikit-learn==1.6.1->-r requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rishu\anaconda3\lib\site-packages (from nltk==3.9.1->-r requirements.txt (line 5)) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\rishu\anaconda3\lib\site-packages (from nltk==3.9.1->-r requirements.txt (line 5)) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rishu\anaconda3\lib\site-packages (from requests==2.32.3->-r requirements.txt (line 7)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rishu\anaconda3\lib\site-packages (from requests==2.32.3->-r requirements.txt (line 7)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rishu\anaconda3\lib\site-packages (from requests==2.32.3->-r requirements.txt (line 7)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rishu\anaconda3\lib\site-packages (from requests==2.32.3->-r requirements.txt (line 7)) (2024.8.30)
# Requirement already satisfied: jinja2 in c:\users\rishu\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit==1.44.1->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\rishu\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit==1.44.1->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: toolz in c:\users\rishu\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit==1.44.1->-r requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: colorama in c:\users\rishu\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit==1.44.1->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\rishu\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.44.1->-r requirements.txt (line 1)) (4.0.7)
# Requirement already satisfied: six>=1.5 in c:\users\rishu\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\rishu\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.44.1->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rishu\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit==1.44.1->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\rishu\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.44.1->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rishu\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.44.1->-r requirements.txt (line 1)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rishu\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.44.1->-r requirements.txt (line 1)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rishu\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.44.1->-r requirements.txt (line 1)) (0.10.6)
# Downloading streamlit-1.44.1-py3-none-any.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/9.8 MB 11.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.2/9.8 MB 10.1 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.8 MB 9.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.8 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.8 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 8.0 MB/s eta 0:00:00
# Downloading numpy-2.2.4-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 6.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.9/12.6 MB 7.0 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/12.6 MB 8.1 MB/s eta 0:00:01
#    -------------------- ------------------- 6.6/12.6 MB 7.9 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.6 MB 7.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.6 MB 7.3 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 7.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 6.5 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.5 MB 6.7 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.5 MB 6.3 MB/s eta 0:00:02
#    ------------- -------------------------- 3.9/11.5 MB 6.3 MB/s eta 0:00:02
#    ------------------ --------------------- 5.2/11.5 MB 6.1 MB/s eta 0:00:02
#    --------------------- ------------------ 6.3/11.5 MB 6.0 MB/s eta 0:00:01
#    ------------------------- -------------- 7.3/11.5 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.5 MB 5.4 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.5 MB 5.4 MB/s eta 0:00:01
# Note: you may need to restart the kernel to use updated packages.
#    ------------------------------------ --- 10.5/11.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 5.4 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp312-cp312-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.1 MB 6.1 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.1 MB 5.8 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.1 MB 5.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/11.1 MB 5.4 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.1 MB 5.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.1 MB 5.3 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.1 MB 5.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.1 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.1 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 5.6 MB/s eta 0:00:00
# Installing collected packages: numpy, pandas, scikit-learn, streamlit
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.1
#     Uninstalling scikit-learn-1.5.1:
#       Successfully uninstalled scikit-learn-1.5.1
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.37.1
#     Uninstalling streamlit-1.37.1:
#       Successfully uninstalled streamlit-1.37.1
# Successfully installed numpy-2.2.4 pandas-2.2.3 scikit-learn-1.6.1 streamlit-1.44.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\rishu\anaconda3\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\rishu\anaconda3\Lib\site-packages\~andas'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\rishu\anaconda3\Lib\site-packages\~klearn'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.4 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.4 which is incompatible.

# %%
cd src
# Out:
# C:\Users\rishu\Desktop\movie-recommendation-app-repo-main\src

# %%
pyhton preprocess.py
# Out:
#   Cell In[49], line 1
#     pyhton preprocess.py
#            ^
# SyntaxError: invalid syntax

# %%
streamlit run main.py
